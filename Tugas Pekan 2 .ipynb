# %% [markdown]
# ## **ASSIGNMENT**
#
# 1. Import data
# 2. Cek Data Kosong
# 3. Korelasi antar variable, dan jelaskan maksudnya
# 4. Cari minimal 3 Insight Menarik, bebas boleh analisis deskriptif, filtering kondisional, atau sorting.
# 5. lakukan 1 Binning pada data. bebas.
#
# Selamat mengerjakan!

# %% [markdown]
# ## **Metadata**
# - battery_power = Kapasitas baterai (mAh)
# - blue = Support Bluetooth
# - clock_speed = Kecepatan microprocessor
# - dual_sim = Support Dual Sim
# - fc = Resolusi Kamera Depan
# - four_g = Support 4G
# - int_memory = Kapasitas Memori internal
# - m_dep = Ketebelan device
# - mobile_wt = Berat Device
# - n_cores = Jumlah Core dari processor
# - pc = Resolusi Kamera Utama
# - px_ height = Resolusi Tinggi Layar
# - px_width = Resolusi Lebar Layar
# - ram = Kapasitas RAM
# - sc._h = Tinggi Layar
# - sc._w = Lebar Lavar
# - talk time = Total waktu pemakaian normal
# - three_g = Support 3G
# - touch_screen = Support lavar sentuh
# - wifi = Support Wifi
# - price range = Kelas harga (output)

# %% [markdown]
# ### **Import Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import dates
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### **1. Data Loading**

# %%
df = pd.read_csv('/Users/muhammadipink/Documents/B. Personal/Bootcamp/Sanbercode/Kelas Karyawan/Soal Tugas Pekan 2.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# ### **Data Inspection**

# %%
# Check data structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# ### **2. Data Preprocessing**

# %%
# check null value 

df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_class      0
# dtype: int64

# %% [markdown]
# **Tidak ada data yang kosong**

# %%
df.price_class.value_counts()
# Out:
# 0    1000
# 1    1000
# Name: price_class, dtype: int64

# %%
a=sns.countplot(data=df,x="blue",palette="Greens")
a.set_xticklabels(["There is not","There is"])
plt.show()

# %% [markdown]
# ### **3. Exploratory Data Analysis**

# %%
# Check Descriptive Statistic
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
# Checking Correlation
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
# Visualize Correlation
plt = plt.figure(figsize=(12,11))
sns.heatmap(df.corr(), fmt=".1f", cmap='Blues', annot= True).set(title='Correlation Score')
# Out:
# [Text(0.5, 1.0, 'Correlation Score')]

# %% [markdown]
# #### **Analisa Korelasi**
#
# 1. **[ram] berkorelasi positif dengan [price_class] - coef 0.8 (Kuat)**
# 2. [pc] berkorelasi positif dengan [fc] - coef 0.6
# 3. [px_width] berkorelasi positif dengan [px_height] - coef 0.6
#
# > Insight:
# Kelas harga sebuah HP/mobile phone ditentukan berdasarkan kapasitas RAM
# Hal ini terlihat dari korelasi positif yang sangat kuat bahwa semakin besar nilai kapasitas RAM maka semakin besar juga nilai kelas harganya.

# %% [markdown]
# ### **4. Other Findings**

# %%
# Regression 'battery_power' & 'ram'
sns.jointplot(x='battery_power', y='ram', data=df, kind='reg')

# %% [markdown]
# > Berdasarkan distribusi data bisa dilihat tidak ada pola korelasi yang terbentuk

# %%
# Join Plot 'price_class' & 'ram'
sns.jointplot(x='price_class', y='ram', data=df, kind='hex')

# %% [markdown]
# > Disini bisa dilihat bahwa ternyata ada HP dengan kapasitas RAM moderat (cukup) yang berada pada 2 kategori harga (Mahal & Murah). **Apabila pertimbangan membeli lebih mengutamakan kapasitas RAM maka HP dengan kapasitas RAM tertinggi (2000 - 2500 MB) yang berada pada price_class 0 (murah) adalah the good deal**

# %%
sns.jointplot(x='price_class', y='pc', data=df, kind='kde')

# %% [markdown]
# > Disini bisa dilihat bahwa garis kernel density pada HP mahal (1) sebagian besar berada pada tingkat resolusi 6-11 Megapixel yang mana nilai resolusi tersebut sangat banyak didapati pada HP dengan kategori murah (0). **Jadi hampir tidak ada perbedaan HP mahal atau murah dari sisi resolusi kamera**

# %% [markdown]
# ### **4. Data Binning**

# %%
sns.displot(df.ram, kde=True, bins=100)

# %%
# Data Binning
df_bin = df[['price_class', 'ram']]
df_bin['ram_category'] = pd.cut(df_bin.ram, bins=[0, 1500, 3000, 4000], labels=['Low Performance', 'Medium Performance', 'High Performance'])
df_bin
# Out:
# /var/folders/s4/g960cnw17h790dqwlfb286680000gn/T/ipykernel_2682/244301777.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bin['ram_category'] = pd.cut(df_bin.ram, bins=[0, 1500, 3000, 4000], labels=['Low Performance', 'Medium Performance', 'High Performance'])
#       price_class   ram        ram_category
# 0               0  2549  Medium Performance
# 1               1  2631  Medium Performance
# 2               1  2603  Medium Performance
# 3               1  2769  Medium Performance
# 4               0  1411     Low Performance
# ...           ...   ...                 ...
# 1995            0   668     Low Performance
# 1996            1  2032  Medium Performance
# 1997            1  3057    High Performance
# ...

# %%
# Visualize ['ram_category']
df_bin.ram_category.value_counts().plot(kind='bar', title='RAM by Category')
# Out:
# <AxesSubplot: title={'center': 'RAM by Category'}>
